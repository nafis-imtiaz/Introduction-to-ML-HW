# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = 'E:/UNCC/UNCC ML/Housing.csv'
sample = pd.DataFrame(pd.read_csv(file_path))
sample.head(3)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished

# %%
# Converting the strings to values

list1 =  ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea']
list2 = ['furnishingstatus']

# Defining the map function
def map1(x):
    return x.map({'yes': 1, 'no': 0})

def map2(x):
    return x.map({'furnished': 1, 'semi-furnished': 0})
    
sample[list1] = sample[list1].apply(map1)
sample[list2] = sample[list2].apply(map2)

sample.head(3)
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
#
#    furnishingstatus
# 0               1.0
# 1               1.0
# 2               0.0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
# Normalizing every values except 'price' which is output and parameters with binary values ('yes/no' and 'furnished/semi-furnished').
num_vars = ['area', 'bedrooms', 'bathrooms', 'stories', 'parking']

sample[num_vars] = scaler.fit_transform(sample[num_vars])
sample.head(3)
# Out:
#       price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 0  13300000  0.396564       0.6   0.333333  0.666667         1          0
# 1  12250000  0.502405       0.6   1.000000  1.000000         1          0
# 2  12250000  0.571134       0.4   0.333333  0.333333         1          0
#
#    basement  hotwaterheating  airconditioning   parking  prefarea  \
# 0         0                0                1  0.666667         1
# 1         0                0                1  1.000000         0
# 2         1                0                0  0.666667         1
#
#    furnishingstatus
# 0               1.0
# 1               1.0
# 2               0.0

# %%
sample1 = sample[['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']]
sample1.head(3)
# Out:
#       price      area  bedrooms  bathrooms   stories   parking
# 0  13300000  0.396564       0.6   0.333333  0.666667  0.666667
# 1  12250000  0.502405       0.6   1.000000  1.000000  1.000000
# 2  12250000  0.571134       0.4   0.333333  0.333333  0.666667

# %%
from sklearn.model_selection import train_test_split

# Splitting the training and validation sets.
np.random.seed(0)
df_train, df_test = train_test_split(sample1, train_size = 0.8, test_size = 0.2, random_state = 100)
y_train = df_train.pop('price')
X_train = df_train
y_val = df_test.pop('price')
X_test = df_test

# %%
# Creating the numpy arrays.
X_p1_train = np.c_[np.ones((len(X_train), 1)), X_train]
X_p1_val = np.c_[np.ones((len(X_test), 1)), X_test]

y_p1_train = y_train.to_numpy()
y_p1_val = y_val.to_numpy()

train_losses = []
val_losses = []

# %%
# Setting the values for gradient desent calculation.
learning_rate = 0.01
lam = 0.01
iterations = 100
m = len(y_train)
n = len(y_val)
w = np.random.randn(X_p1_train.shape[1])

# %%
# The calculation loop for weights and losses
for i in range(iterations):
    gradient = (2/m) * X_p1_train.T.dot(X_p1_train.dot(w) - y_p1_train)

    w = w*(1 - learning_rate*(lam/m)) - learning_rate * gradient

    train_loss = (1/m) * np.sum(np.square(X_p1_train.dot(w) - y_p1_train))
    val_loss = (1/n) * np.sum(np.square(X_p1_val.dot(w) - y_p1_val))

    train_losses.append(train_loss)
    val_losses.append(val_loss)
print(f'The values of the weights: {w}')
# Out:
# The values of the weights: [3189560.26259839  996570.69517146 1343537.00352666  567499.93954322
#  1134713.73820756 1000463.87851042]

# %%
# Plotting the training and validation losses
plt.plot(train_losses, label="Training Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Iteration")
plt.ylabel("Losses")
plt.legend()
plt.title("Training and Validation Loss Over Iterations for 5 Normalized Parameters (Learning Rate 0.01, Lambda 0.0)")
plt.show()

# %%
sample1 = sample[['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
                  'parking', 'prefarea']]
sample1.head(3)
# Out:
#       price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 0  13300000  0.396564       0.6   0.333333  0.666667         1          0
# 1  12250000  0.502405       0.6   1.000000  1.000000         1          0
# 2  12250000  0.571134       0.4   0.333333  0.333333         1          0
#
#    basement  hotwaterheating  airconditioning   parking  prefarea
# 0         0                0                1  0.666667         1
# 1         0                0                1  1.000000         0
# 2         1                0                0  0.666667         1

# %%
from sklearn.model_selection import train_test_split

# Splitting the training and validation sets.
np.random.seed(0)
df_train, df_test = train_test_split(sample1, train_size = 0.8, test_size = 0.2, random_state = 100)
y_train = df_train.pop('price')
X_train = df_train
y_val = df_test.pop('price')
X_test = df_test

# %%
# Creating the numpy arrays.
X_p1_train = np.c_[np.ones((len(X_train), 1)), X_train]
X_p1_val = np.c_[np.ones((len(X_test), 1)), X_test]

y_p1_train = y_train.to_numpy()
y_p1_val = y_val.to_numpy()

train_losses = []
val_losses = []

# %%
m = len(y_train)
n = len(y_val)
w = np.random.randn(X_p1_train.shape[1])

# %%
# The calculation loop for weights and losses
for i in range(iterations):
    gradient = (2/m) * X_p1_train.T.dot(X_p1_train.dot(w) - y_p1_train)

    w = w*(1 - learning_rate*(lam/m)) - learning_rate * gradient

    train_loss = (1/m) * np.sum(np.square(X_p1_train.dot(w) - y_p1_train))
    val_loss = (1/n) * np.sum(np.square(X_p1_val.dot(w) - y_p1_val))

    train_losses.append(train_loss)
    val_losses.append(val_loss)
print(f'The values of the weights: {w}')
# Out:
# The values of the weights: [1863992.51911357  613651.105102    829043.94427522  422902.12744979
#   762894.47635792 1578688.28868112  424303.09156262  608827.98757348
#   197835.53737942  867776.98073697  631716.60489916  553271.03536436]

# %%
# Plotting the training and validation losses
plt.plot(train_losses, label="Training Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Iteration")
plt.ylabel("Losses")
plt.legend()
plt.title("Training and Validation Loss Over Iterations for 10 Normalized Parameters (Learning Rate 0.01, Lambda 100)")
plt.show()
